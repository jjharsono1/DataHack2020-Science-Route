# %% [markdown]
# # BEGINNER TRACK SD DATA HACKS 2020

# %%
import pandas as pd
import numpy as np

# %%
housing = pd.read_csv("SD1970_housing.csv")
housing
# Out:
#               Tract name  Block group Place Name Total housing units  \
# 0     Census Tract 1                1  San Diego                 302
# 1     Census Tract 1                2  San Diego                 234
# 2     Census Tract 1                3  San Diego                 176
# 3     Census Tract 1                4  San Diego                 159
# 4     Census Tract 1                5  San Diego                 209
# ...                  ...          ...        ...                 ...
# 1259  Census Tract 199              3        NaN                  99
# 1260  Census Tract 199              3        NaN                  89
# 1261  Census Tract 199              9        NaN                 138
# 1262  Census Tract 199              9        NaN                 224
# 1263  Census Tract 199              9      Vista                   3
#
#      Total owner occupied real $ aggregate (total) value of housing units  \
# 0                                        $7,783,750.00
# ...

# %%
population = pd.read_csv("SD1970_population.csv")
population
# Out:
#        Census Tract Name  Block Group Place Name Total persons  \
# 0     Census Tract 1                1  San Diego           901
# 1     Census Tract 1                2  San Diego           683
# 2     Census Tract 1                3  San Diego           532
# 3     Census Tract 1                4  San Diego           421
# 4     Census Tract 1                5  San Diego           489
# ...                  ...          ...        ...           ...
# 1259  Census Tract 199              3        NaN           271
# 1260  Census Tract 199              3        NaN           259
# 1261  Census Tract 199              9        NaN           444
# 1262  Census Tract 199              9        NaN           550
# 1263  Census Tract 199              9      Vista             6
#
#      Male persons age under 5 years Male persons age 5 years  \
# 0                                31                        6
# 1                                28                        2
# ...

# %% [markdown]
# # DATA WRANGLING

# %%
[i.split(" ")[0] == 'Male' for i in population.columns]
# Out:
# [False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
# ...

# %%
population["Total Male Persons"] = population.where(population.columns.split(" ")[0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-91b89d44fdec> in <module>
# ----> 1 population["Total Male Persons"] = population.where(population.columns)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in where(self, cond, other, inplace, axis, level, errors, try_cast)
#    9274         other = com.apply_if_callable(other, self)
#    9275         return self._where(
# -> 9276             cond, other, inplace, axis, level, errors=errors, try_cast=try_cast
#    9277         )
#    9278
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _where(self, cond, other, inplace, axis, level, errors, try_cast)
#    8994                 cond = np.asanyarray(cond)
#    8995             if cond.shape != self.shape:
# -> 8996                 raise ValueError("Array conditional must be same shape as " "self")
# ...
